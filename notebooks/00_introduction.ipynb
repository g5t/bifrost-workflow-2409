# %% [markdown]
# # BIFROST data transformation
# ## McStas &rightarrow; NeXus

# %% [markdown]
# <img src="generated/readout_mcstas.svg" width="100%"/>

# %% [markdown]
# ### Simple system simulations for transformation validation
# | simulated | type | S(**Q**,E)  |
# |:---------:|------|-------------|
# |  &check;  | flat-field incoherent elastic scatterer | &propto; &delta;(E) |
# |  &check;  | quantum oscillator like incoherent scatterer | &propto; &Sigma; &delta;(E - E<sub><i>i</i></sub>) |
# |  &check;  | coherent quasiparticle excitations | &propto; &delta;(E - \|**Q** - **G**\|) |

# %% [markdown]
# ## Transformation workflow
# Mostly simple function with defined inputs & outputs
#
# ```python
# def energy(ki: IncidentWavenumber, kf: FinalWavenumber) -> EnergyTransfer:
#     from scipp.constants import hbar, neutron_mass
#     return hbar ** 2 * (ki ** 2 - kf ** 2) / 2 / neutron_mass
# ```
#
# leverages `sciline` to convert list of functions and input/output types to calculation graph
#
# <img src='data:image/svg+xml,%3C%3Fxml version%3D"1.0" encoding%3D"UTF-8" standalone%3D"no"%3F%3E%0A%3C!DOCTYPE svg PUBLIC "-%2F%2FW3C%2F%2FDTD SVG 1.1%2F%2FEN"%0A "http%3A%2F%2Fwww.w3.org%2FGraphics%2FSVG%2F1.1%2FDTD%2Fsvg11.dtd"%3E%0A%3C!-- Generated by graphviz version 9.0.0 (20230911.1827)%0A --%3E%0A%3C!-- Pages%3A 1 --%3E%0A%3Csvg width%3D"576pt" height%3D"148pt"%0A viewBox%3D"0.00 0.00 576.00 148.34" xmlns%3D"http%3A%2F%2Fwww.w3.org%2F2000%2Fsvg" xmlns%3Axlink%3D"http%3A%2F%2Fwww.w3.org%2F1999%2Fxlink"%3E%0A%3Cg id%3D"graph0" class%3D"graph" transform%3D"scale(0.720105 0.720105) rotate(0) translate(4 202)"%3E%0A%3Cpolygon fill%3D"none" stroke%3D"none" points%3D"-4%2C4 -4%2C-202 795.88%2C-202 795.88%2C4 -4%2C4"%2F%3E%0A%3C!-- AnalyzerDetectorVector --%3E%0A%3Cg id%3D"node1" class%3D"node"%3E%0A%3Ctitle%3EAnalyzerDetectorVector%3C%2Ftitle%3E%0A%3Cpolygon fill%3D"none" stroke%3D"%230099dc" points%3D"151.38%2C-198 4.12%2C-198 4.12%2C-162 151.38%2C-162 151.38%2C-198"%2F%3E%0A%3Ctext text-anchor%3D"middle" x%3D"77.75" y%3D"-174.95" font-family%3D"Times%2Cserif" font-size%3D"14.00" fill%3D"%230099dc"%3EAnalyzerDetectorVector%3C%2Ftext%3E%0A%3C%2Fg%3E%0A%3C!-- ess.spectroscopy.indirect.kf.final_wavenumber_FinalWavenumber --%3E%0A%3Cg id%3D"node6" class%3D"node"%3E%0A%3Ctitle%3Eess.spectroscopy.indirect.kf.final_wavenumber_FinalWavenumber%3C%2Ftitle%3E%0A%3Cellipse fill%3D"none" stroke%3D"%230099dc" cx%3D"284.82" cy%3D"-122" rx%3D"80.52" ry%3D"18"%2F%3E%0A%3Ctext text-anchor%3D"middle" x%3D"284.82" y%3D"-116.95" font-family%3D"Times%2Cserif" font-size%3D"14.00" fill%3D"%230099dc"%3Efinal_wavenumber%3C%2Ftext%3E%0A%3C%2Fg%3E%0A%
3C%2Ftext%3E%0A%3C%2Fg%3E%0A%3C!-- ess.spectroscopy.indirect.ki.incident_wavenumber_IncidentWavenumber --%3E%0A%3Cg id%3D"node10" class%3D"node"%3E%0A%3Ctitle%3Eess.spectroscopy.indirect.ki.incident_wavenumber_IncidentWavenumber%3C%2Ftitle%3E%0A%3Cellipse fill%3D"none" stroke%3D"%230099dc" cx%3D"284.82" cy%3D"-45" rx%3D"93.32" ry%3D"18"%2F%3E%0A%3Ctext text-anchor%3D"middle" x%3D"284.82" y%3D"-39.95" font-family%3D"Times%2Cserif" font-size%3D"14.00" fill%3D"%230099dc"%3Eincident_wavenumber%3C%2Ftext%3E%0A%3C%2Fg%3E%0A%3C!-- IncidentSlowness%26%2345%3B%26gt%3Bess.spectroscopy.indirect.ki.incident_wavenumber_IncidentWavenumber --%3E%0A%3Cg id%3D"edge8" class%3D"edge"%3E%0A%3Ctitle%3EIncidentSlowness%26%2345%3B%26gt%3Bess.spectroscopy.indirect.ki.incident_wavenumber_IncidentWavenumber%3C%2Ftitle%3E%0A%3Cpath fill%3D"none" stroke%3D"%230099dc" d%3D"M133.7%2C-25.24C152.71%2C-27.74 174.52%2C-30.61 195.52%2C-33.37"%2F%3E%0A%3Cpolygon fill%3D"%230099dc" stroke%3D"%230099dc" points%3D"194.87%2C-36.82 205.24%2C-34.65 195.78%2C-29.88 194.87%2C-36.82"%2F%3E%0A%3C%2Fg%3E%0A%3C!-- ess.spectroscopy.indirect.ki.incident_wavenumber_IncidentWavenumber%26%2345%3B%26gt%3BIncidentWavenumber --%3E%0A%3Cg id%3D"edge9" class%3D"edge"%3E%0A%3Ctitle%3Eess.spectroscopy.indirect.ki.incident_wavenumber_IncidentWavenumber%26%2345%3B%26gt%3BIncidentWavenumber%3C%2Ftitle%3E%0A%3Cpath fill%3D"none" stroke%3D"%230099dc" d%3D"M373.66%2C-50.89C383.27%2C-51.54 393%2C-52.19 402.47%2C-52.82"%2F%3E%0A%3Cpolygon fill%3D"%230099dc" stroke%3D"%230099dc" points%3D"402.15%2C-56.31 412.36%2C-53.49 402.62%2C-49.33 402.15%2C-56.31"%2F%3E%0A%3C%2Fg%3E%0A%3C%2Fg%3E%0A%3C%2Fsvg%3E%0A' width='80%'>

# %% [markdown]
# ## Workflow requirements status
#
# | Status  | Description | per |
# |:-------:|-------------|-----|
# | &check; | propagate `frame_time` to sample position | event |
# | &check; | calculate final (energy, wavelength, wavenumber, wavevector, velocity) from secondary geometry | pixel |
# | &check; | unwrap `frame_time` at sample to find `wall_time` at sample | event |
# | &check; | calculate incident (energy, wavelength, wavenumber, wavevector, velocity) from chopper cascade | event |
# | &check; | calculate energy transfer and lab-frame momentum transfer | event |
# | &check; | convert lab-frame momentum transfer to sample-table momentum-transfer | event |
# | &check; | normalize by incident wavelength-dependent flux | event |
# | ongoing | normalize by detector efficiency, analyzer reflectivity, etc. | pixel |
# | ongoing | output user-defined E<sub>f</sub>-grouped datasets for further analysis | |
# | to-do | scale normalized intensity to absolute intensity units | event |
